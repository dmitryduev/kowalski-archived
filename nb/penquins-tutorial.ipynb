# %% [markdown]
# # `penquins`: a `python` client library for `kowalski`

# %% [markdown]
# *`penquins` - Processing ENormous Queries of ztf Users INStantaneously - Zero to Hero*
#
# In this tutorial, we will explore the details of how to programmatically query `kowalski` with `python >3.6`. We will also cover the best practices and pro tips.

# %% [markdown]
# ## Installation
#
# [`penuquins`](https://github.com/dmitryduev/kowalski/blob/master/penquins.py) is very lightweight and only depends on `pymongo` and `requests`. Use `pip` to install it into your environment:

# %%
#!pip install git+https://github.com/dmitryduev/kowalski.git

# %% [markdown]
# ## Quick start

# %%
from IPython.core.display import display, HTML
import json

from penquins import Kowalski

# %% [markdown]
# For security, let us store the access credentials in a `json` file `secrets_penquins.json`:

# %%
secrets = {
    "kowalski": {
        "username": "YOUR_USERNAME",
        "password": "YOUR_PASSWORD"
    }
}

with open('secrets.json', 'w') as f:
    json.dump(secrets, f)

# %% [markdown]
# Load the credentials and initialize a `Kowalski` object:

# %%
with open('secrets_penquins.json', 'r') as f:
    secrets = json.load(f)

k = Kowalski(username=secrets['kowalski']['username'], password=secrets['kowalski']['password'])

# %% [markdown]
# By default, the `Kowalski` object will try to connect to the `kowalski` instance running at Caltech using the following parameters:
# ```python
# protocol='https', host='kowalski.caltech.edu', port=443
# ```
#
# You can explicitely set those if you are connecting to another instance of `kowalski`.
#
# Set `verbose=True` if you want more feedback from `Kowalski`.

# %% [markdown]
# Let us check that the connection is healthy:

# %%
connection_ok = k.check_connection()
print(f'Connection OK: {connection_ok}')
# Out:
# Connection OK: True

# %% [markdown]
# Now let us construct a simple query that should return the `candid` of a ZTF alert from the `ZTF_alerts` collection and run it.
#
# _Please see below for more info on the available query types and how to (efficiently) construct them_.

# %%
q = {"query_type": "find",
     "query": {
         "catalog": "ZTF_alerts",
         "filter": {"candid": 714287740515015072},
#          "filter": {"objectId": "ZTF18acrkaks"},
         "projection": {"_id": 0, "candid": 1},
     }
     }
r = k.query(query=q)
display(r)
# Out:
# {'user': 'admin',
#  'kwargs': {},
#  'status': 'done',
#  'result_data': {'query_result': [{'candid': 714287740515015072}]}}

# %% [markdown]
# This query will block the execution of your program until it receives the result or when it hits the default timeout, which is set to _24 hours_. You can manually set up the query timeout in _milliseconds_ after which it will be killed on the server:

# %%
q['kwargs'] = {'max_time_ms': 10}
r = k.query(query=q)
r
# Out:
# {'user': 'admin',
#  'kwargs': {'max_time_ms': 10},
#  'status': 'done',
#  'result_data': {'query_result': [{'candid': 714287740515015072}]}}

# %% [markdown]
# Starting from `penquins` version `1.0.0`, queries are no longer registered in the database and saved to disk _by default_,
# which provides significant execution speed improvement.
#
# You can enqueue a query on the server. This may be useful for long-running queries:

# %%
q['kwargs'] = {'enqueue_only': True}
r = k.query(query=q)
display(r)
# Out:
# {'status': 'enqueued', 'query_id': 'acc32170eaffa3364e7aee28c6ccfbfa'}

# %% [markdown]
# Executing this query will return a query `id` that can be then used to retrieve the query result:

# %%
qid = r['query_id']
result = k.get_query(query_id=qid, part='result')
display(result)
# Out:
# {'task_id': 'acc32170eaffa3364e7aee28c6ccfbfa',
#  'result': '{"query_result": [{"candid": 714287740515015072}]}'}

# %% [markdown]
# You can also retrieve the original query:

# %%
result = k.get_query(query_id=qid, part='task')
display(result)
# Out:
# {'task_id': 'acc32170eaffa3364e7aee28c6ccfbfa',
#  'result': '{"query_type": "find", "query": {"catalog": "ZTF_alerts", "filter": {"candid": 714287740515015072}, "projection": {"_id": 0, "candid": 1}}, "kwargs": {"enqueue_only": true, "_id": "o6nt5ntuhivu9ty0t00j2rtlbcvoqyct"}, "user": "admin"}'}

# %% [markdown]
# Or delete the query from Kowalski:

# %%
result = k.delete_query(query_id=qid)
display(result)
# Out:
# {'message': 'success'}

# %% [markdown]
# By default, the queries/results stored on `kowalski` are deleted after five days.
# To override this, set a manual expiration interval in days:

# %%
q["kwargs"] = {"query_expiration_interval": 30}

# %% [markdown]
# ## Error management
#
# Note: `kowalski` will refuse connection if your installed version of `penquins` is outdated.
#
# In case a query fails, the result will contain the traceback error message. Using our running example query:

# %%
q = {"query_type": "find",
     "query": {
         "catalog": "ZTF_alerts",
         "filter": {"candid": 714287740515015072},
#          "filter": {"objectId": "ZTF18acrkaks"},
         "projection": {"_id": 0, "candid": 1, "objectId": 0},
     }
     }

r = k.query(query=q)
# r
print(r['msg'])
# Out:
# Traceback (most recent call last):
#   File "/app/server.py", line 957, in execute_query
#     query_result['query_result'] = await _select.to_list(length=None)
#   File "/usr/local/lib/python3.6/site-packages/motor/core.py", line 1133, in _to_list
#     result = get_more_result.result()
#   File "/usr/local/lib/python3.6/concurrent/futures/thread.py", line 56, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/usr/local/lib/python3.6/site-packages/pymongo/cursor.py", line 1140, in _refresh
#     self.__send_message(q)
#   File "/usr/local/lib/python3.6/site-packages/pymongo/cursor.py", line 1010, in __send_message
#     helpers._check_command_response(first)
#   File "/usr/local/lib/python3.6/site-packages/pymongo/helpers.py", line 155, in _check_command_response
#     raise OperationFailure(msg % errmsg, code, response)
# pymongo.errors.OperationFailure: Projection cannot have a mix of inclusion and exclusion.

# %% [markdown]
# ## Querying `kowalski`
#
# `Kowalski`'s API supports several types of queries: `info`, `cone_search`, `general_search`, and a number of frequently-used sub-types of general search (`find`, _todo:_ `find_one`, _todo:_ `aggregate`).
#
# `Kowalski` uses a `MongoDB` `NoQSL` database on the backend. The query syntax is therefore based on the `MongoDB` query language, `MQL`. It might look unusual if you are experienced in `SQL`, but feels quite natural if you are using `python`.

# %% [markdown]
# ### General advice, recommendations, and best practices
#
# `Kowalski` gives a lot of power to its users, so it is expected that it is used responsibly.

# %% [markdown]
# - Check available catalogs:

# %%
q = {"query_type": "info",
     "query": {
         "command": "catalog_names"
     }
     }
r = k.query(query=q)
display(r['result_data']['query_result'])
# Out:
# ['sdss_ellipticals',
#  'mzls_ellipticals',
#  'milliquas_v6',
#  'legacysurveys_photoz_DR7',
#  'legacysurveys_photoz_DR6',
#  'cfht_w3_photozs',
#  'ZTF_sources_20190614',
#  'ZTF_exposures_20190614',
#  'ZTF_alerts',
#  'ZTF_20181220',
#  'ZTF_20180919',
#  'TNS',
#  'TIC_7',
#  'TGSS_ADR1',
#  'RFC_2018d',
#  'RFC_2017c',
#  'PanSTARRS1',
#  'NVSS_41',
#  'Known_lenses_20180901',
#  'IPHAS_DR2',
#  'Gaia_DR2_light_curves',
#  'Gaia_DR2_WD',
#  'Gaia_DR2_2MASS_best_neighbour',
#  'Gaia_DR2',
#  'FIRST_20141217',
#  'CLU_20190625',
#  'CLU_20190406',
#  'CLU_20181213V2',
#  'CLU_20180513',
#  'CLU_20170106',
#  'AllWISE',
#  'AMSG_20180302',
#  '2MASS_XSC',
#  '2MASS_PSC']

# %% [markdown]
# - To check the available "fields" (think "columns" in SQL/table-speak) for a particular catalog, explore the last ingested document.
#     - `MongoDB` does not enforce any schema by default meaning that the contents of individual documents in a collection/catalog may differ from one another.

# %%
q = {"query_type": "general_search",
     "query": "db['ZTF_alerts'].find().sort([('_id', -1)]).limit(1)"
     }
r = k.query(query=q)
r['result_data']['query_result'][0]
# Out:
# {'_id': '920488006315015009_ZTF19abfrnrh',
#  'schemavsn': '3.3',
#  'publisher': 'ZTF (www.ztf.caltech.edu)',
#  'objectId': 'ZTF19abfrnrh',
#  'candid': 920488006315015009,
#  'candidate': {'jd': 2458674.9880093,
#   'fid': 2,
#   'pid': 920488006315,
#   'diffmaglim': 20.085472106933594,
#   'pdiffimfilename': 'ztf_20190710488009_000549_zr_c16_o_q4_scimrefdiffimg.fits',
#   'programpi': 'Kulkarni',
#   'programid': 1,
#   'candid': 920488006315015009,
#   'isdiffpos': 't',
#   'tblid': 9,
#   'nid': 920,
#   'rcid': 63,
#   'field': 549,
#   'xpos': 1058.8603515625,
#   'ypos': 2556.45166015625,
#   'ra': 352.5333651,
#   'dec': 13.8743573,
#   'magpsf': 19.041229248046875,
#   'sigmapsf': 0.10750275105237961,
#   'chipsf': 1.5496622323989868,
#   'magap': 18.833799362182617,
#   'sigmagap': 0.1315000057220459,
#   'distnr': 6.386654376983643,
#   'magnr': 23.083999633789062,
#   'sigmagnr': 0.3440000116825104,
#   'chinr': 0.7850000262260437,
#   'sharpnr': -0.4580000042915344,
#   'sky': -0.006382666993886232,
#   'magdiff': -0.20743000507354736,
#   'fwhm': 1.9700000286102295,
#   'classtar': 0.9810000061988831,
#   'mindtoedge': 524.0484008789062,
#   'magfromlim': 1.2516721487045288,
#   'seeratio': 1.196689486503601,
#   'aimage': 0.8610000014305115,
#   'bimage': 0.7300000190734863,
#   'aimagerat': 0.4370558261871338,
#   'bimagerat': 0.37055838108062744,
#   'elong': 1.1794520616531372,
#   'nneg': 3,
#   'nbad': 0,
#   'rb': 0.9328571557998657,
#   'ssdistnr': 0.0,
#   'ssmagnr': 19.299999237060547,
#   'ssnamenr': '112406',
#   'sumrat': 1.0,
#   'magapbig': 18.814199447631836,
#   'sigmagapbig': 0.16529999673366547,
#   'ranr': 352.5316504,
#   'decnr': 13.873693,
#   'sgmag1': 21.106700897216797,
#   'srmag1': 19.877700805664062,
#   'simag1': 19.267000198364258,
#   'szmag1': 18.977100372314453,
#   'sgscore1': 0.9970830082893372,
#   'distpsnr1': 10.336372375488281,
#   'ndethist': 1,
#   'ncovhist': 64,
#   'jdstarthist': 2458674.9880093,
#   'jdendhist': 2458674.9880093,
#   'scorr': 17.5480976104736,
#   'tooflag': 0,
#   'objectidps1': 124653525304040479,
#   'objectidps2': 124653525344307885,
#   'sgmag2': -999.0,
#   'srmag2': 21.818099975585938,
#   'simag2': 21.185400009155273,
#   'szmag2': 20.814599990844727,
#   'sgscore2': 0.0035416700411587954,
#   'distpsnr2': 24.87616729736328,
#   'objectidps3': 124653525381496634,
#   'sgmag3': 21.495399475097656,
#   'srmag3': 20.984800338745117,
#   'simag3': 20.699399948120117,
#   'szmag3': 20.567899703979492,
#   'sgscore3': 0.1604049950838089,
#   'distpsnr3': 26.17915916442871,
#   'nmtchps': 4,
#   'rfid': 549120263,
#   'jdstartref': 2458281.963738,
#   'jdendref': 2458434.670313,
#   'nframesref': 15,
#   'rbversion': 't17_f5_c3',
#   'dsnrms': 14.952946662902832,
#   'ssnrms': 21.500730514526367,
#   'dsdiff': -6.547783851623535,
#   'magzpsci': 26.072229385375977,
#   'magzpsciunc': 9.934799891198054e-06,
#   'magzpscirms': 0.04636000096797943,
#   'nmatches': 589,
#   'clrcoeff': 0.11786600202322006,
#   'clrcounc': 1.4565500350727234e-05,
#   'zpclrcov': -1.1150000318593811e-05,
#   'zpmed': 26.152000427246094,
#   'clrmed': 0.671999990940094,
#   'clrrms': 0.3092629909515381,
#   'neargaia': 10.336105346679688,
#   'neargaiabright': -999.0,
#   'maggaia': 19.741836547851562,
#   'maggaiabright': -999.0,
#   'exptime': 30.0,
#   'drb': 0.9999836683273315,
#   'drbversion': 'd6_m7'},
#  'prv_candidates': [{'jd': 2458647.9702199,
#    'fid': 1,
#    'pid': 893470216315,
#    'diffmaglim': 19.96969985961914,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0613/470185/ztf_20190613470185_000549_zg_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 893,
#    'rcid': 63,
#    'field': 549,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 25.631000518798828,
#    'magzpsciunc': 1.9163600882166065e-05,
#    'magzpscirms': 0.03852799907326698,
#    'clrcoeff': -0.05155010148882866,
#    'clrcounc': 3.1633499020244926e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458652.9565856,
#    'fid': 2,
#    'pid': 898456586315,
#    'diffmaglim': 19.614999771118164,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0618/456586/ztf_20190618456586_000549_zr_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 898,
#    'rcid': 63,
#    'field': 549,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.001399993896484,
#    'magzpsciunc': 1.1342600373609457e-05,
#    'magzpscirms': 0.030809199437499046,
#    'clrcoeff': 0.11890300363302231,
#    'clrcounc': 1.6675699953339063e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458655.9422917,
#    'fid': 2,
#    'pid': 901442296315,
#    'diffmaglim': 19.532800674438477,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0621/442280/ztf_20190621442280_000549_zr_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 901,
#    'rcid': 63,
#    'field': 549,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.058300018310547,
#    'magzpsciunc': 1.3331999980437104e-05,
#    'magzpscirms': 0.03324199840426445,
#    'clrcoeff': 0.12466300278902054,
#    'clrcounc': 1.9449100363999605e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458655.9784606,
#    'fid': 1,
#    'pid': 901478466315,
#    'diffmaglim': 19.32349967956543,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0621/478449/ztf_20190621478449_000549_zg_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 901,
#    'rcid': 63,
#    'field': 549,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.17329978942871,
#    'magzpsciunc': 2.8459300665417686e-05,
#    'magzpscirms': 0.03922040015459061,
#    'clrcoeff': -0.029280999675393105,
#    'clrcounc': 5.8291698223911226e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458663.9600116,
#    'fid': 1,
#    'pid': 909460016315,
#    'diffmaglim': 20.360000610351562,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0629/459977/ztf_20190629459977_000549_zg_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 909,
#    'rcid': 63,
#    'field': 549,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 25.947900772094727,
#    'magzpsciunc': 1.6282499927910976e-05,
#    'magzpscirms': 0.036770500242710114,
#    'clrcoeff': -0.03622420132160187,
#    'clrcounc': 2.4706299882382154e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458666.9225463,
#    'fid': 2,
#    'pid': 912422546315,
#    'diffmaglim': 20.61479949951172,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0702/422512/ztf_20190702422512_000549_zr_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 912,
#    'rcid': 63,
#    'field': 549,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.054100036621094,
#    'magzpsciunc': 6.611289791180752e-06,
#    'magzpscirms': 0.023471800610423088,
#    'clrcoeff': 0.1133200004696846,
#    'clrcounc': 9.625149687053636e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458669.9192824,
#    'fid': 2,
#    'pid': 915419286315,
#    'diffmaglim': 20.64900016784668,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0705/419155/ztf_20190705419155_000549_zr_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 915,
#    'rcid': 63,
#    'field': 549,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.0625,
#    'magzpsciunc': 6.109240075602429e-06,
#    'magzpscirms': 0.022620199248194695,
#    'clrcoeff': 0.1100739985704422,
#    'clrcounc': 8.973689546110108e-06,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458669.9610648,
#    'fid': 1,
#    'pid': 915461066315,
#    'diffmaglim': 20.938800811767578,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0705/461065/ztf_20190705461065_000549_zg_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 915,
#    'rcid': 63,
#    'field': 549,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.17259979248047,
#    'magzpsciunc': 1.0370699783379678e-05,
#    'magzpscirms': 0.02930550090968609,
#    'clrcoeff': -0.05871070176362991,
#    'clrcounc': 1.528370012238156e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458672.9268634,
#    'fid': 1,
#    'pid': 918426866315,
#    'diffmaglim': 20.922300338745117,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0708/426863/ztf_20190708426863_000549_zg_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 918,
#    'rcid': 63,
#    'field': 549,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.12700080871582,
#    'magzpsciunc': 1.0498700248717796e-05,
#    'magzpscirms': 0.029732199385762215,
#    'clrcoeff': -0.057725999504327774,
#    'clrcounc': 1.548349973745644e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458672.9630093,
#    'fid': 2,
#    'pid': 918463006315,
#    'diffmaglim': 20.84149932861328,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0708/463009/ztf_20190708463009_000549_zr_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 918,
#    'rcid': 63,
#    'field': 549,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.053600311279297,
#    'magzpsciunc': 6.609279807889834e-06,
#    'magzpscirms': 0.023472599685192108,
#    'clrcoeff': 0.10640999674797058,
#    'clrcounc': 9.700570444692858e-06,
#    'rbversion': 't17_f5_c3'}],
#  'cutoutScience': {'fileName': 'candid920488006315015009_pid920488006315_targ_sci.fits.gz',
#   'stampData': b'\x1f\x8b\x08\x00"\xd1%]\x02\x03\xed\x9bWp\x94W\xd7\xa5;ge\x91\x93\xc8Xd\x90E\xc6\xb0\x16`\x0c\x180\xd9d0\xc9X`r\x06\x93L\xce\xd9\xe4d\x911\x06\x8cI\xb6\x01cr\x0e\x02\x04\x08!\x84rhuK\xad\xce=\xfb\xfb\xe7njnf\xe6\xaf\xb9\xf2\xa9\xa2\xa4\x02\xf5y\xdfs\xf6\xdek=\x0b\x8a\x9e_|\xd9\xbdK\xfb\xa8\xa8VQQ\xbd\xa2\xfe\x1b\x16\xbe\xe8\xd5\xfd\x8b~\xff\xb5\xdf\xff\xba\xea6n\xf4\x7f\xbe_\xd7\xb6\xfd\xbe\xe8\x19\xf5\xbf\xdd/*\xea\xffv\xbf\x86\xff\xfb\xfdb\x1b\xff_\xee\xd7\xe8\xbfo?\xf4\xee\xfaE\xaf\xff:o\xcdv]\xff\xe7o\xd5\xfc\x7f\xa9G\xfb\xae\xed\xa2\xfe]\xff\xae\x7f\xd7\xbf\xeb\xdf\xf5\xef\xfaw\xfd\xbb\xfe]\xff}\x8b\xc6}\xa3\xe0x\x91AE\xf5\x1e\xb0f\xc7\xa1\xc0\xd7\x0b\xaej9\xc8i}\x99\xcaIQ\xc8\x8a<He\x99.\xf80<\x8aZ\xcdq*^\xdf\x82\xad\xe1IxB\xddT\x06W\x86\xe7|05\xb3G\xc3\xb1\xe4O\xb8\xfejN\xc3\xf0\xcf\x90Yq0\x95\xca\x9a448\x82\xec\x8e]\xa9\xb1\xac\x85W\x1f\r\xef\xe8\xd6Tl\n\xc0\xfa\xec(\xfc_\xaf\x80sj\x02\xcd\xb7\xc61\xb4\xdd8\x96m\xd9\n\x99\x1b\x8f"\xad\xdc\x9f\xf0\x8d\xdc\x00\xfb\xbax\x04\xfa\x9c\xa4\xbe\xdd\x11\xd8\xa6FS\x9dV\x82\x06\xa7\x1d\xfe2)p\xcd\xb4\xe0\xcd\xfe8\xaa\xef\xd4\xa0n{\x17\x9a\xcf\xa4\xd0\xf0\xd5\x16\x06\x05\x1a\xc1yC\x01g\xc38
\x12\xc3\x97\xc7\xbe\xbe\n\xee\xf8n\'n}\x16\xc5^\xa9\\\xd8*\xbc\x1e%\x1c\x83\xf1K\x93\r\xd7m\x10\x80k\x97\xb5rJZ\x8f\x99\xaeU\x15V\t-\x02\x91\x95\x95pB\xc5\x1e*\xcc&\xc3\x85\xb56t\x82\xcd\x15X\xd2\xfb\x86\xdc&[\xe0\xf6\xf9\xddL\xc0\xd6\x97<\x19S\x03\xa7\\.\xe2z\x93\xa7\\\xf7\xb1\xcb,!\xa0\x12|\xa5\xdf\xa2\xdc\xc7\xfd\xf06u1\xee\x92\x13c\x0b\xee\xa5\x10\x91\xbf\xa7 9\x9cq7d\x01\x8e\x07n\x06\xe7\x98.\xbe\xc97\x17\x18<{\x03\xbf\tL\x83\x9b\xf2\x0b\xb9\xba\xbf\x80\xf7\xea\xfe2\x89\x93jP\xa6\xfa\x9en\xf2L\xe1/\x7fI\xb8\x84\xd0|\xa8\xaf\xdd\x02\xf2\x11<&\xfc\xf1<\xb6D\xa7\x90\x8e\xe4\r`\x1ai\xcb\xd5\x99\x953\x9e\xe4}\xbadr&\xa8]\xd4\x81\x92\xbaeLrt\x07V\xf8\xbe$N\xdf\x9eb\xca=\x01\xec\xfa]\xc2%\x8b-C\xed\xd3uT2\xcb\x97\xe9\x8e\x98\x10\xf3\xb8\xb5\xf8\xb7] ...
#  'cross_matches': {},
#  'classifications': {'braai': 0.9999303817749023, 'braai_version': 'd6_m9'},
#  'coordinates': {'epoch': 2458674.9880093,
#   'radec_str': ['23:30:08.0076', '13:52:27.686'],
#   'radec_geojson': {'type': 'Point',
#    'coordinates': [172.53336510000003, 13.8743573]},
#   'radec_rad': [6.15286794413027, 0.24215321648311064],
#   'radec_deg': [352.5333651, 13.8743573]}}

# %% [markdown]
# - Before querying a catalog, explore its stats and available indexes.
#
#     - You want to minimize the required I/O operations. Indexes on "fields" (think "columns" in `SQL`/table-speak) provide a fast way to find the location of a "document" (think catalog entry) on disk for further retrieval, or even to fetch the field value if no other data is needed (so-called "covered queries").
#     - Indexes may be compound to speed-up multi-field queries / enable multi-field covered queries.
#     - Whenever possible, construct your queries to use indexes. A query that cannot use an index will initiate a full collection (catalog) scan, which for large catalogs may be very costly in terms of I/O = time.
#
# - If possible, construct your queries in such a way that the result is small(er) in size. Think of a way to "slice" your query into smaller chunks; this is usually good for performance.

# %% [markdown]
# To illustrate the advice given above, let us assume we want to query the `ZTF_alerts` catalog.

# %%
# print large numbers in human-readable format
# !pip install humanize
import humanize
# Out:
# Requirement already satisfied: humanize in /Users/dmitryduev/anaconda3/lib/python3.7/site-packages (0.5.1)

# %%
q = {"query_type": "info",
     "query": {
         "command": "catalog_info",
         "catalog": "ZTF_alerts"
     }
     }
r = k.query(query=q)
size = r['result_data']['query_result']['size']
count = r['result_data']['query_result']['count']
avg_doc_size = r['result_data']['query_result']['avgObjSize']

print(f'Catalog size: {humanize.naturalsize(size)}')
print(f'Number of entries: {humanize.intword(count)}')
print(f'Average entry size: {humanize.naturalsize(avg_doc_size)}')
# Out:
# Catalog size: 14.3 TB
# Number of entries: 140.2 million
# Average entry size: 101.9 kB

# %% [markdown]
# That's a lot of data! You definitely want to minimize I/O for your queries! Let us explore the available indexes:

# %%
q = {"query_type": "info",
     "query": {
         "command": "index_info",
         "catalog": "ZTF_alerts"
     }
     }
r = k.query(query=q)
indexes = [v['key'] for k, v in r['result_data']['query_result'].items()]
for ii, ind in enumerate(indexes):
    print(f'index #{ii+1}: {ind}')
# Out:
# index #1: [['_id', 1]]
# index #2: [['objectId', 1]]
# index #3: [['candid', 1]]
# index #4: [['candidate.field', 1]]
# index #5: [['candidate.fwhm', 1]]
# index #6: [['candidate.magpsf', 1]]
# index #7: [['candidate.rb', 1]]
# index #8: [['candidate.jd', 1], ['candidate.programid', 1]]
# index #9: [['candidate.nid', 1]]
# index #10: [['coordinates.radec_geojson', '2dsphere'], ['_id', 1]]
# index #11: [['coordinates.radec_geojson', '2dsphere']]
# index #12: [['candidate.jd', 1], ['_id', 1]]
# index #13: [['candidate.jd', 1], ['candidate.rb', 1], ['_id', 1]]
# index #14: [['candidate.jd', 1], ['candidate.field', 1], ['candidate.rb', 1], ['_id', 1]]
# index #15: [['candidate.pdiffimfilename', 1]]
# index #16: [['candidate.field', 1], ['candidate.rcid', 1], ['candidate.jd', 1], ['candidate.magpsf', 1], ['candidate.sigmapsf', 1]]
# index #17: [['candidate.jd', 1], ['candidate.rb', 1], ['candidate.xpos', 1], ['candidate.ypos', 1]]
# index #18: [['candidate.jd', -1], ['candidate.rb', -1], ['candidate.distnr', 1], ['candidate.magnr', 1], ['candidate.magpsf', 1], ['candid', -1]]
# index #19: [['candidate.field', 1], ['candidate.rcid', 1], ['candidate.programid', 1], ['candidate.fid', 1], ['candidate.jd', 1], ['candidate.diffmaglim', 1]]
# index #20: [['candidate.jd', -1], ['classifications.braai', -1], ['candidate.rb', -1], ['candid', -1]]
# index #21: [['candidate.pid', 1]]
# index #22: [['candidate.jd', -1], ['classifications.braai', -1], ['candid', -1]]
# index #23: [['candidate.jd', 1], ['candidate.field', 1], ['candidate.rb', 1], ['candidate.ndethist', 1], ['candidate.magpsf', 1], ['candidate.isdiffpos', 1], ['objectId', 1]]

# %% [markdown]
# ### Query examples
#
# *Sample cone search 1*
#
# Get all objects from the `ZTF_alerts` catalog within `8` arcseconds for two sky positions
# `(173.5155088, 33.0845502), (172.1345, 30.5412)`
# and return, `_id`'s, `objectId`'s, `candidate.rcid`'s, and `candidate.rb`'s.

# %%
q = {"query_type": "cone_search",
     "object_coordinates": {
         "radec": "[(173.5155088, 33.0845502), (172.1345, 30.5412)]", 
         "cone_search_radius": "8",
         "cone_search_unit": "arcsec"
     },
     "catalogs": {
         "ZTF_alerts": {
             "filter": {},
             "projection": {
                 "objectId": 1,
                 "candidate.rcid": 1,
                 "candidate.rb": 1
             }
         }
     }
     }
r = k.query(query=q)
data = r['result_data']
display(data)
# Out:
# {'ZTF_alerts': {'(173_5155088, 33_0845502)': [{'_id': '404387932115015001_ZTF18aabcyiy',
#     'objectId': 'ZTF18aabcyiy',
#     'candidate': {'rcid': 21, 'rb': 0.3766666650772095}}],
#   '(172_1345, 30_5412)': []}}
