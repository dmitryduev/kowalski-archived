# %% [markdown]
# # `penquins`: a `python` client library for `kowalski`

# %% [markdown]
# *`penquins` - Processing ENormous Queries of ztf Users INStantaneously - Zero to Hero*
#
# In this tutorial, we will explore the details of how to programmatically query `kowalski` with `python >3.6`. We will also cover the best practices and pro tips.

# %% [markdown]
# ## Installation
#
# [`penuquins`](https://github.com/dmitryduev/kowalski/blob/master/penquins.py) is very lightweight and only depends on `pymongo` and `requests`. Use `pip` to install it into your environment:

# %%
#!pip install git+https://github.com/dmitryduev/kowalski.git

# %% [markdown]
# ## Quick start

# %%
from IPython.core.display import display, HTML
import json

from penquins import Kowalski

# %% [markdown]
# For security, let us store the access credentials in a `json` file `secrets_penquins.json`:

# %%
secrets = {
    "kowalski": {
        "username": "YOUR_USERNAME",
        "password": "YOUR_PASSWORD"
    }
}

with open('secrets.json', 'w') as f:
    json.dump(secrets, f)

# %% [markdown]
# Load the credentials and initialize a `Kowalski` object:

# %%
with open('secrets_penquins.json', 'r') as f:
    secrets = json.load(f)

k = Kowalski(username=secrets['kowalski']['username'], password=secrets['kowalski']['password'])

# %% [markdown]
# By default, the `Kowalski` object will try to connect to the `kowalski` instance running at Caltech using the following parameters:
# ```python
# protocol='https', host='kowalski.caltech.edu', port=443
# ```
#
# You can explicitely set those if you are connecting to another instance of `kowalski`.
#
# Set `verbose=True` if you want more feedback from `Kowalski`.

# %% [markdown]
# Let us check that the connection is healthy:

# %%
connection_ok = k.check_connection()
print(f'Connection OK: {connection_ok}')
# Out:
# Connection OK: True

# %% [markdown]
# Now let us construct a simple query that should return the `candid` of a ZTF alert from the `ZTF_alerts` collection and run it.
#
# _Please see below for more info on the available query types and how to (efficiently) construct them_.

# %%
q = {"query_type": "find",
     "query": {
         "catalog": "ZTF_alerts",
         "filter": {"candid": 714287740515015072},
#          "filter": {"objectId": "ZTF18acrkaks"},
         "projection": {"_id": 0, "candid": 1},
     }
     }
r = k.query(query=q)
display(r)
# Out:
# {'user': 'admin',
#  'kwargs': {},
#  'status': 'done',
#  'result_data': {'query_result': [{'candid': 714287740515015072}]}}

# %% [markdown]
# This query will block the execution of your program until it receives the result or when it hits the default timeout, which is set to _24 hours_. You can manually set up the query timeout in _milliseconds_ after which it will be killed on the server:

# %%
q['kwargs'] = {'max_time_ms': 10}
r = k.query(query=q)
r
# Out:
# {'user': 'admin',
#  'kwargs': {'max_time_ms': 10},
#  'status': 'done',
#  'result_data': {'query_result': [{'candid': 714287740515015072}]}}

# %% [markdown]
# Starting from `penquins` version `1.0.0`, queries are no longer registered in the database and saved to disk _by default_,
# which provides significant execution speed improvement.
#
# You can enqueue a query on the server. This may be useful for long-running queries:

# %%
q['kwargs'] = {'enqueue_only': True}
r = k.query(query=q)
display(r)
# Out:
# {'status': 'enqueued', 'query_id': 'dd9d58a87763f43c092f53776d54bee8'}

# %% [markdown]
# Executing this query will return a query `id` that can be then used to retrieve the query result:

# %%
qid = r['query_id']
result = k.get_query(query_id=qid, part='result')
display(result)
# Out:
# {'task_id': 'dd9d58a87763f43c092f53776d54bee8',
#  'result': '{"query_result": [{"candid": 714287740515015072}]}'}

# %% [markdown]
# You can also retrieve the original query:

# %%
result = k.get_query(query_id=qid, part='task')
display(result)
# Out:
# {'task_id': 'dd9d58a87763f43c092f53776d54bee8',
#  'result': '{"query_type": "find", "query": {"catalog": "ZTF_alerts", "filter": {"candid": 714287740515015072}, "projection": {"_id": 0, "candid": 1}}, "kwargs": {"enqueue_only": true, "_id": "wj0akfadwhopao7kc2zx2xkmc0eembzq"}, "user": "admin"}'}

# %% [markdown]
# Or delete the query from Kowalski:

# %%
result = k.delete_query(query_id=qid)
display(result)
# Out:
# {'message': 'success'}

# %% [markdown]
# By default, the queries/results stored on `kowalski` are deleted after five days.
# To override this, set a manual expiration interval in days:

# %%
q["kwargs"] = {"query_expiration_interval": 30}

# %% [markdown]
# ## Error management
#
# Note: `kowalski` will refuse connection if your installed version of `penquins` is outdated.
#
# In case a query fails, the result will contain the traceback error message. Using our running example query:

# %%
q = {"query_type": "find",
     "query": {
         "catalog": "ZTF_alerts",
         "filter": {"candid": 714287740515015072},
#          "filter": {"objectId": "ZTF18acrkaks"},
         "projection": {"_id": 0, "candid": 1, "objectId": 0},
     }
     }

r = k.query(query=q)
# r
print(r['msg'])
# Out:
# Traceback (most recent call last):
#   File "/app/server.py", line 957, in execute_query
#     query_result['query_result'] = await _select.to_list(length=None)
#   File "/usr/local/lib/python3.6/site-packages/motor/core.py", line 1133, in _to_list
#     result = get_more_result.result()
#   File "/usr/local/lib/python3.6/concurrent/futures/thread.py", line 56, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/usr/local/lib/python3.6/site-packages/pymongo/cursor.py", line 1140, in _refresh
#     self.__send_message(q)
#   File "/usr/local/lib/python3.6/site-packages/pymongo/cursor.py", line 1010, in __send_message
#     helpers._check_command_response(first)
#   File "/usr/local/lib/python3.6/site-packages/pymongo/helpers.py", line 155, in _check_command_response
#     raise OperationFailure(msg % errmsg, code, response)
# pymongo.errors.OperationFailure: Projection cannot have a mix of inclusion and exclusion.

# %% [markdown]
# ## Querying `kowalski`
#
# `Kowalski`'s API supports several types of queries: `info`, `cone_search`, `general_search`, and a number of frequently-used sub-types of general search (`find`, _todo:_ `find_one`, _todo:_ `aggregate`).
#
# `Kowalski` uses a `MongoDB` `NoQSL` database on the backend. The query syntax is therefore based on the `MongoDB` query language, `MQL`. It might look unusual if you are experienced in `SQL`, but feels quite natural if you are using `python`.

# %% [markdown]
# ### General advice, recommendations, and best practices
#
# `Kowalski` gives a lot of power to its users, so it is expected that it is used responsibly.

# %% [markdown]
# - Check available catalogs:

# %%
q = {"query_type": "info",
     "query": {
         "command": "catalog_names"
     }
     }
r = k.query(query=q)
display(r['result_data']['query_result'])
# Out:
# ['sdss_ellipticals',
#  'mzls_ellipticals',
#  'milliquas_v6',
#  'legacysurveys_photoz_DR7',
#  'legacysurveys_photoz_DR6',
#  'cfht_w3_photozs',
#  'ZTF_sources_20190614',
#  'ZTF_exposures_20190614',
#  'ZTF_alerts',
#  'ZTF_20181220',
#  'ZTF_20180919',
#  'TNS',
#  'TIC_7',
#  'TGSS_ADR1',
#  'RFC_2018d',
#  'RFC_2017c',
#  'PanSTARRS1',
#  'NVSS_41',
#  'Known_lenses_20180901',
#  'IPHAS_DR2',
#  'Gaia_DR2_light_curves',
#  'Gaia_DR2_WD',
#  'Gaia_DR2_2MASS_best_neighbour',
#  'Gaia_DR2',
#  'FIRST_20141217',
#  'CLU_20190625',
#  'CLU_20190406',
#  'CLU_20181213V2',
#  'CLU_20180513',
#  'CLU_20170106',
#  'AllWISE',
#  'AMSG_20180302',
#  '2MASS_XSC',
#  '2MASS_PSC']

# %% [markdown]
# - To check the available "fields" (think "columns" in SQL/table-speak) for a particular catalog, explore the last ingested document.
#     - `MongoDB` does not enforce any schema by default meaning that the contents of individual documents in a collection/catalog may differ from one another.
#     - Make sure the field you are querying actually exists! For example, if you make a typo and query for a non-existent field, the database will have to perform a full collection scan looking for entries that have the mis-typed field.

# %%
q = {"query_type": "general_search",
     "query": "db['ZTF_alerts'].find().sort([('_id', -1)]).limit(1)"
     }
r = k.query(query=q)
r['result_data']['query_result'][0]
# Out:
# {'_id': '922488716315015013_ZTF19abgaywu',
#  'schemavsn': '3.3',
#  'publisher': 'ZTF (www.ztf.caltech.edu)',
#  'objectId': 'ZTF19abgaywu',
#  'candid': 922488716315015013,
#  'candidate': {'jd': 2458676.9887153,
#   'fid': 2,
#   'pid': 922488716315,
#   'diffmaglim': 20.187538146972656,
#   'pdiffimfilename': 'ztf_20190712488704_000398_zr_c16_o_q4_scimrefdiffimg.fits',
#   'programpi': 'Kulkarni',
#   'programid': 1,
#   'candid': 922488716315015013,
#   'isdiffpos': 't',
#   'tblid': 13,
#   'nid': 922,
#   'rcid': 63,
#   'field': 398,
#   'xpos': 757.9771118164062,
#   'ypos': 2180.863037109375,
#   'ra': 13.6525871,
#   'dec': -0.4146375,
#   'magpsf': 18.879215240478516,
#   'sigmapsf': 0.20663587749004364,
#   'chipsf': 11.129026412963867,
#   'magap': 19.366100311279297,
#   'sigmagap': 0.20559999346733093,
#   'distnr': 2.7380359172821045,
#   'magnr': 22.30699920654297,
#   'sigmagnr': 0.164000004529953,
#   'chinr': 0.8209999799728394,
#   'sharpnr': -0.27900001406669617,
#   'sky': 0.1464983969926834,
#   'magdiff': 0.4868850111961365,
#   'fwhm': 1.7000000476837158,
#   'classtar': 0.972000002861023,
#   'mindtoedge': 757.9771118164062,
#   'magfromlim': 0.8214389681816101,
#   'seeratio': 1.3172483444213867,
#   'aimage': 0.3580000102519989,
#   'bimage': 0.24699999392032623,
#   'aimagerat': 0.2105882316827774,
#   'bimagerat': 0.14529411494731903,
#   'elong': 1.4493926763534546,
#   'nneg': 12,
#   'nbad': 0,
#   'rb': 0.18714286386966705,
#   'ssdistnr': -999.0,
#   'ssmagnr': -999.0,
#   'ssnamenr': 'null',
#   'sumrat': 0.5462158918380737,
#   'magapbig': 19.511699676513672,
#   'sigmagapbig': 0.30090001225471497,
#   'ranr': 13.6529379,
#   'decnr': -0.415323,
#   'sgmag1': -999.0,
#   'srmag1': -999.0,
#   'simag1': 21.598100662231445,
#   'szmag1': -999.0,
#   'sgscore1': 0.05479170009493828,
#   'distpsnr1': 16.651058197021484,
#   'ndethist': 1,
#   'ncovhist': 124,
#   'jdstarthist': 2458676.9887153,
#   'jdendhist': 2458676.9887153,
#   'scorr': 25.3901042938232,
#   'tooflag': 0,
#   'objectidps1': 107500136485945850,
#   'objectidps2': 107500136472481250,
#   'sgmag2': -999.0,
#   'srmag2': 22.058399200439453,
#   'simag2': 21.837600708007812,
#   'szmag2': 21.40060043334961,
#   'sgscore2': 0.34477099776268005,
#   'distpsnr2': 19.722396850585938,
#   'objectidps3': 107510136552870177,
#   'sgmag3': -999.0,
#   'srmag3': 21.496000289916992,
#   'simag3': 21.03030014038086,
#   'szmag3': 20.622699737548828,
#   'sgscore3': 0.8057799935340881,
#   'distpsnr3': 23.912580490112305,
#   'nmtchps': 4,
#   'rfid': 398120263,
#   'jdstartref': 2458289.965255,
#   'jdendref': 2458367.877928,
#   'nframesref': 16,
#   'rbversion': 't17_f5_c3',
#   'dsnrms': 38.329444885253906,
#   'ssnrms': 39.2333869934082,
#   'dsdiff': -0.9039421081542969,
#   'magzpsci': 26.022214889526367,
#   'magzpsciunc': 1.4048299817659426e-05,
#   'magzpscirms': 0.04353899881243706,
#   'nmatches': 329,
#   'clrcoeff': 0.10377100110054016,
#   'clrcounc': 1.8446900867274962e-05,
#   'zpclrcov': -1.4860000192129519e-05,
#   'zpmed': 26.100000381469727,
#   'clrmed': 0.7799999713897705,
#   'clrrms': 0.33553698658943176,
#   'neargaia': 25.03117561340332,
#   'neargaiabright': -999.0,
#   'maggaia': 18.512344360351562,
#   'maggaiabright': -999.0,
#   'exptime': 30.0,
#   'drb': 0.0032884099055081606,
#   'drbversion': 'd6_m7'},
#  'prv_candidates': [{'jd': 2458662.9447454,
#    'fid': 1,
#    'pid': 908444746315,
#    'diffmaglim': 20.22100067138672,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0628/444745/ztf_20190628444745_000398_zg_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 908,
#    'rcid': 63,
#    'field': 398,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.020099639892578,
#    'magzpsciunc': 1.7752799976733513e-05,
#    'magzpscirms': 0.028766600415110588,
#    'clrcoeff': -0.025607600808143616,
#    'clrcounc': 2.4503100576112047e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458662.9646065,
#    'fid': 2,
#    'pid': 908464606315,
#    'diffmaglim': 20.320899963378906,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0628/464606/ztf_20190628464606_000398_zr_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 908,
#    'rcid': 63,
#    'field': 398,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.02720069885254,
#    'magzpsciunc': 1.3738000234297942e-05,
#    'magzpscirms': 0.025221800431609154,
#    'clrcoeff': 0.10967999696731567,
#    'clrcounc': 1.803720078896731e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458667.9422222,
#    'fid': 1,
#    'pid': 913442226315,
#    'diffmaglim': 20.54170036315918,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0703/442222/ztf_20190703442222_000398_zg_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 913,
#    'rcid': 63,
#    'field': 398,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.041200637817383,
#    'magzpsciunc': 1.442869961465476e-05,
#    'magzpscirms': 0.026639999821782112,
#    'clrcoeff': -0.029133599251508713,
#    'clrcounc': 1.9220000467612408e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458670.9417014,
#    'fid': 1,
#    'pid': 916441706315,
#    'diffmaglim': 20.603900909423828,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0706/441701/ztf_20190706441701_000398_zg_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 916,
#    'rcid': 63,
#    'field': 398,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.046600341796875,
#    'magzpsciunc': 1.6759400750743225e-05,
#    'magzpscirms': 0.02862600050866604,
#    'clrcoeff': -0.038228098303079605,
#    'clrcounc': 2.2551699657924473e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458673.9480093,
#    'fid': 2,
#    'pid': 919448006315,
#    'diffmaglim': 20.47480010986328,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0709/448009/ztf_20190709448009_000398_zr_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 919,
#    'rcid': 63,
#    'field': 398,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.036500930786133,
#    'magzpsciunc': 9.940429663402028e-06,
#    'magzpscirms': 0.021723400801420212,
#    'clrcoeff': 0.10803300142288208,
#    'clrcounc': 1.2956100363226142e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458673.9771875,
#    'fid': 1,
#    'pid': 919477186315,
#    'diffmaglim': 20.501800537109375,
#    'pdiffimfilename': '/ztf/archive/sci/2019/0709/477188/ztf_20190709477188_000398_zg_c16_o_q4_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 919,
#    'rcid': 63,
#    'field': 398,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.131200790405273,
#    'magzpsciunc': 1.7570200725458562e-05,
#    'magzpscirms': 0.029149500653147697,
#    'clrcoeff': -0.039384398609399796,
#    'clrcounc': 2.3503800548496656e-05,
#    'rbversion': 't17_f5_c3'}],
#  'cutoutScience': {'fileName': 'candid922488716315015013_pid922488716315_targ_sci.fits.gz',
#   'stampData': b'\x1f\x8b\x08\x00\\t(]\x02\x03\xed\x99e\xb4\x15W\xd7\xa5\xb1k\xc7\xb5\xaaN\x1d?W\xb8\xb8Cpypw\t\xee\xee\xee\xc1\xdd!\xb8\x06\x0f\xee\x12\xdc!\xc1\xdd\x83\xbb\x06\xb7^\xef\xd7\xffz\xf4\x9f\xee\xfeF\xff\xcaf0\xee\x1dG\xaaj\xef\xb5\xd6\x9c\xcf\x84je*T._"\x14*\x18\nU\x0f\xfd7\xacbe\xaaW.S\xfb\xbf\xae\xf7\xbf\xaeL9\xb2\xff\x9f_\xafb\xd1\xdae\xaa\x85\xfe\xb7\xd7\x0b\x85\xfeo\xaf\x97\xed\x7f\x7f\xbd\xdc9\xfe/\xaf\x97\xfd\xbf\xefz\xc5jT,S\xfd\xbf\xf6\x9b\xb6x\xc5\xff\xf9R\xda\xff\x97z\x94\xa8X<\xf4\xef\xfaw\xfd\xbb\xfe]\xff\xae\x7f\xd7\xbf\xeb\xdf
#   'radec_deg': [13.6525871, -0.4146375]}}

# %% [markdown]
# - Before querying a catalog, explore its stats and available indexes.
#
#     - You want to minimize the required I/O operations. Indexes on "fields" (think "columns" in `SQL`/table-speak) provide a fast way to find the location of a "document" (think catalog entry) on disk for further retrieval, or even to fetch the field value if no other data is needed (so-called "covered queries").
#     - Indexes may be compound to speed-up multi-field queries / enable multi-field covered queries.
#     - Whenever possible, construct your queries to use indexes. A query that cannot use an index will initiate a full collection (catalog) scan, which for large catalogs may be very costly in terms of I/O = time.
#
# - If possible, construct your queries in such a way that the result is small(er) in size. Think of a way to "slice" your query into smaller chunks; this is usually good for performance.

# %% [markdown]
# To illustrate the advice given above, let us assume we want to query the `ZTF_alerts` catalog.

# %%
# print large numbers in human-readable format
# !pip install humanize
import humanize
# Out:
# Requirement already satisfied: humanize in /Users/dmitryduev/anaconda3/lib/python3.7/site-packages (0.5.1)

# %%
q = {"query_type": "info",
     "query": {
         "command": "catalog_info",
         "catalog": "ZTF_alerts"
     }
     }
r = k.query(query=q)
size = r['result_data']['query_result']['size']
count = r['result_data']['query_result']['count']
avg_doc_size = r['result_data']['query_result']['avgObjSize']

print(f'Catalog size: {humanize.naturalsize(size)}')
print(f'Number of entries: {humanize.intword(count)}')
print(f'Average entry size: {humanize.naturalsize(avg_doc_size)}')
# Out:
# Catalog size: 14.3 TB
# Number of entries: 140.9 million
# Average entry size: 101.7 kB

# %% [markdown]
# That's a lot of data! You definitely want to minimize I/O for your queries! Let us explore the available indexes:

# %%
q = {"query_type": "info",
     "query": {
         "command": "index_info",
         "catalog": "ZTF_alerts"
     }
     }
r = k.query(query=q)

# indexes = [v['key'] for k, v in r['result_data']['query_result'].items()]
# for ii, ind in enumerate(indexes):
#     print(f'index #{ii+1}: {ind}')

indexes = r['result_data']['query_result']
for ii, (k, v) in enumerate(indexes.items()):
    print(f'index #{ii+1}: "{k}"\n{v["key"]}\n')
# Out:
# index #1: "_id_"
# [['_id', 1]]
#
# index #2: "objectId_1"
# [['objectId', 1]]
#
# index #3: "candid_1"
# [['candid', 1]]
#
# index #4: "candidate.field_1"
# [['candidate.field', 1]]
#
# index #5: "candidate.fwhm_1"
# [['candidate.fwhm', 1]]
#
# index #6: "candidate.magpsf_1"
# [['candidate.magpsf', 1]]
#
# index #7: "candidate.rb_1"
# [['candidate.rb', 1]]
#
# index #8: "candidate.jd_1_candidate.programid_1"
# [['candidate.jd', 1], ['candidate.programid', 1]]
#
# index #9: "candidate.nid_1"
# [['candidate.nid', 1]]
#
# index #10: "coordinates.radec_geojson_2dsphere___id_1"
# [['coordinates.radec_geojson', '2dsphere'], ['_id', 1]]
#
# index #11: "coordinates.radec_geojson_2dsphere"
# [['coordinates.radec_geojson', '2dsphere']]
#
# index #12: "candidate_jd___id_1"
# [['candidate.jd', 1], ['_id', 1]]
#
# index #13: "candidate_jd_1__candidate_rb_1___id_1"
# [['candidate.jd', 1], ['candidate.rb', 1], ['_id', 1]]
#
# index #14: "candidate_jd_1__candidate_field_1__candidate_rb_1___id"
# [['candidate.jd', 1], ['candidate.field', 1], ['candidate.rb', 1], ['_id', 1]]
#
# index #15: "candidate.pdiffimfilename_1"
# [['candidate.pdiffimfilename', 1]]
#
# index #16: "candidate_field_1__candidate_rcid_1__candidate_jd_1__candidate_magpsf_1__candidate_sigmapsf_1"
# [['candidate.field', 1], ['candidate.rcid', 1], ['candidate.jd', 1], ['candidate.magpsf', 1], ['candidate.sigmapsf', 1]]
#
# index #17: "candidate.jd_1__candidate.rb_1__candidate.xpos_1__candidate.ypos_1"
# [['candidate.jd', 1], ['candidate.rb', 1], ['candidate.xpos', 1], ['candidate.ypos', 1]]
#
# index #18: "jd_m1__rb_m1__distnr_1__magnr_1__magpsf_1_candid_m1"
# [['candidate.jd', -1], ['candidate.rb', -1], ['candidate.distnr', 1], ['candidate.magnr', 1], ['candidate.magpsf', 1], ['candid', -1]]
#
# index #19: "limiting_mag"
# [['candidate.field', 1], ['candidate.rcid', 1], ['candidate.programid', 1], ['candidate.fid', 1], ['candidate.jd', 1], ['candidate.diffmaglim', 1]]
#
# index #20: "jd_braai_rb_candid"
# [['candidate.jd', -1], ['classifications.braai', -1], ['candidate.rb', -1], ['candid', -1]]
#
# index #21: "candidate.pid_1"
# [['candidate.pid', 1]]
#
# index #22: "candidate.jd_-1_classifications.braai_-1_candid_-1"
# [['candidate.jd', -1], ['classifications.braai', -1], ['candid', -1]]
#
# index #23: "jd_1__field_1__rb_1__ndethist_1__magpsf_1__isdiffpos_1__objectId_1"
# [['candidate.jd', 1], ['candidate.field', 1], ['candidate.rb', 1], ['candidate.ndethist', 1], ['candidate.magpsf', 1], ['candidate.isdiffpos', 1], ['objectId', 1]]
#
# index #24: "jd_1__programpi_1__programid_1"
# [['candidate.jd', 1], ['candidate.programpi', 1], ['candidate.programid', 1]]

# %% [markdown]
# The database wants to minimize I/O, too, so when you make a query, it will first try to find an index to speed up your query. You can explicitely provide it with a `hint` on what index to try and use (see below).
#
# If the database fails to find such an index, it will have to look at the individual documents on disk.
#
# The same applies if you make a type and query the `ZTF_alerts` catalog for, for example, "objectID" or "candidate.objectId" (both don't exist) instead of "objectId", the database will have to look at _all_ entries in the database.

# %% [markdown]
# ### Query examples
#
# *Sample cone search 1*
#
# Get all objects from the `ZTF_alerts` catalog within `8` arcseconds for two sky positions
# `(173.5155088, 33.0845502), (172.1345, 30.5412)`
# and return, `_id`'s, `objectId`'s, `candidate.rcid`'s, and `candidate.rb`'s.

# %%
q = {"query_type": "cone_search",
     "object_coordinates": {
         "radec": "[(173.5155088, 33.0845502), (172.1345, 30.5412)]", 
         "cone_search_radius": "8",
         "cone_search_unit": "arcsec"
     },
     "catalogs": {
         "ZTF_alerts": {
             "filter": {},
             "projection": {
                 "objectId": 1,
                 "candidate.rcid": 1,
                 "candidate.rb": 1
             }
         }
     }
     }
r = k.query(query=q)
data = r['result_data']
display(data)
# Out:
# {'ZTF_alerts': {'(173_5155088, 33_0845502)': [{'_id': '404387932115015001_ZTF18aabcyiy',
#     'objectId': 'ZTF18aabcyiy',
#     'candidate': {'rcid': 21, 'rb': 0.3766666650772095}}],
#   '(172_1345, 30_5412)': []}}
